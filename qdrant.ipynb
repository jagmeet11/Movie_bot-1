# %%
# %pip install qdrant-client
# %pip install openai
# %pip install tiktoken

# %pip install langchain
# %pip install langchain_openai
# %pip install streamlit

# %%
import qdrant_client
from qdrant_client import QdrantClient
from qdrant_client.http import models
from langchain.vectorstores import Qdrant
import pandas as pd
from langchain.embeddings.openai import OpenAIEmbeddings

# %%
# cluster connection
client = QdrantClient(
    url = 'https://02702cd9-b8bb-4785-bf59-ab7c327443d8.us-east4-0.gcp.cloud.qdrant.io:6333' ,
    port=6333,
    api_key = '_sYptKewmRFnn7bSMfU1DZP1kEz3KXuJ6TzKLfD1-B5LaWfw71kE8w'
)

# %%
vectors_config = models.VectorParams(
    size = 1536,
    distance = models.Distance.COSINE
)

client.create_collection(
    collection_name = 'MyCollection',
    vectors_config = vectors_config
)
# Out:
# True

# %%
OPENAI_API_KEY="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"

embeddings=OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY) # passs the key in here 

vector_store = Qdrant(
    client=client, 
    collection_name="MyCollection", 
    embeddings=embeddings,
)

# %%
data = pd.read_csv('cleaned_movie_data.csv')
data.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901  Terrible Teddy, the Grizzly King         American
# 3          1902            Jack and the Beanstalk         American
# 4          1903               Alice in Wonderland         American
#
#                              Director       Cast    Genre  \
# 0                             Unknown        NaN  unknown
# 1                             Unknown        NaN  unknown
# 2                             Unknown        NaN  unknown
# 3  George S. Fleming, Edwin S. Porter        NaN  unknown
# 4                      Cecil Hepworth  May Clark  unknown
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# ...

# %%
data = data.dropna()

# %%
data = data[:1000]

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.isna().sum()
# Out:
# Release Year        0
# Title               0
# Origin/Ethnicity    0
# Director            0
# Cast                0
# Genre               0
# Plot                0
# dtype: int64

# %%
data = data.reset_index(drop = True)
data.head()
# Out:
#    Release Year                            Title Origin/Ethnicity  \
# 0          1903              Alice in Wonderland         American
# 1          1907                     Daniel Boone         American
# 2          1907  How Brown Saw the Baseball Game         American
# 3          1907                     Laughing Gas         American
# 4          1908         The Adventures of Dollie         American
#
#                                   Director                               Cast  \
# 0                           Cecil Hepworth                          May Clark
# 1  Wallace McCutcheon and Ediwin S. Porter  William Craven, Florence Lawrence
# 2                                  Unknown                            Unknown
# 3                     Edwin Stanton Porter    Bertha Regustus, Edward Boulden
# 4                           D. W. Griffith  Arthur V. Johnson, Linda Arvidson
#
#           Genre                                               Plot
# ...

# %%
chunks = []
for i in range(0, len(data)):
    chunk = ',' .join(f"{col}: {data.iloc[i][col]}" for col in data.columns)
    chunks.append(chunk)

# %%
print(chunks)
# Out:
# ['Release Year: 1903,Title: Alice in Wonderland,Origin/Ethnicity: American,Director: Cecil Hepworth,Cast: May Clark,Genre: unknown,Plot: Alice follows a large white rabbit down a "Rabbit-hole". She finds a tiny door. When she finds a bottle labeled "Drink me", she does, and shrinks, but not enough to pass through the door. She then eats something labeled "Eat me" and grows larger. She finds a fan when enables her to shrink enough to get into the "Garden" and try to get a "Dog" to play with her. She enters the "White Rabbit\'s tiny House," but suddenly resumes her normal size. In order to get out, she has to use the "magic fan." She enters a kitchen, in which there is a cook and a woman holding a baby. She persuades the woman to give her the child and takes the infant outside after the cook starts throwing things around. The baby then turns into a pig and squirms out of her grip. "The Duchess\'s Cheshire Cat" appears and disappears a couple of times to Alice and directs her to the Mad
# ...

# %%
vector_store.add_texts(chunks)
# Out:
# ['8191e17d4e01499b9c2543917241a285',
#  '572c0a3d93e747caaacec2436b05c4d0',
#  '60e15027fbfe44b991487155d06727b7',
#  '8d9200af2a5f4ae58bc9e501cd5a0c9d',
#  'ba417c94599e46aea7c41682dcde087f',
#  '626675d1c7fb4b62b33228b06fa48c6d',
#  'ce9bd79d47b74d3ea36fa01258441161',
#  'e3560372a2a0421288bc2e8f434fac38',
#  '42b078cfd40f4577a579dc7482ceb73d',
#  '21d618e41ffc4e71b4bc7d35531042d8',
#  'e08a21d32d844058808ebf25eb60fe34',
#  '171721a911a8480f98527063b6826acf',
#  '9c2d5dd5297e4dd199a118b48856fe97',
#  '65706f7f4eee4ad6b5d1c95b77471c59',
#  'decd5fd9d7094d1aa9ecf750e122acb4',
#  'ae394742b6404965a468ac0a2421ec1f',
#  '44811b06ee214a38bbb618000cf192d5',
#  'c9784432cadf45288ee905d24cd4294c',
#  '08963f0adf3c405cbe3c2c0f97c1739c',
#  '9689d3fcd178424fadbea6959a2c300a',
#  'f1e51be2ed9f4d8bb5e7cb0f3e27a363',
#  '5215486566ba4633a6848fb8a91c865a',
#  '1a59670200ca49998dc3a0cab1cbee69',
#  '0e04b94208124e6490ab2a2cca031c7d',
#  'c1941cfc4f6a42a0ba3e608d14acbc09',
# ...

# %%
retriever = vector_store.as_retriever()

# %%
retriever.get_relevant_documents('when was alice and wonder land released ?')
# Out:
# [Document(page_content='Release Year: 1903,Title: Alice in Wonderland,Origin/Ethnicity: American,Director: Cecil Hepworth,Cast: May Clark,Genre: unknown,Plot: Alice follows a large white rabbit down a "Rabbit-hole". She finds a tiny door. When she finds a bottle labeled "Drink me", she does, and shrinks, but not enough to pass through the door. She then eats something labeled "Eat me" and grows larger. She finds a fan when enables her to shrink enough to get into the "Garden" and try to get a "Dog" to play with her. She enters the "White Rabbit\'s tiny House," but suddenly resumes her normal size. In order to get out, she has to use the "magic fan." She enters a kitchen, in which there is a cook and a woman holding a baby. She persuades the woman to give her the child and takes the infant outside after the cook starts throwing things around. The baby then turns into a pig and squirms out of her grip. "The Duchess\'s Cheshire Cat" appears and disappears a couple of times to Alice and 
# ...

# %%
# collections = client.get_collection()

# %%
# collections

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts.prompt import PromptTemplate

template = """You are a movie expert and using the {context} answer the user question {question}"""

prompt = PromptTemplate(template= template, input_variables=["question", "context"])

model = ChatOpenAI(model="gpt-3.5-turbo", api_key = OPENAI_API_KEY)
ouput_parser = StrOutputParser()

retriever_2 = vector_store.as_retriever()

rag_chain2 = (
    {
        "context": retriever_2,
        "question": RunnablePassthrough()
     }
     |prompt
     |model
     |StrOutputParser()
)

# %%
rag_chain2.invoke("when is alice in wonderland released?")
# Out:
# 'Alice in Wonderland was released in 1903.'

# %%
rag_chain2.invoke("i want to want a comedy movie, what do i watch")
# Out:
# 'Based on the information provided, I would recommend watching "I Do" (1921) or "Daydreams" (1922) if you are looking for a comedy movie. Both movies fall under the comedy genre and feature humorous plots and gags. Enjoy!'
